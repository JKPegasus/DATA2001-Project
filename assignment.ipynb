# %% [markdown]
# # Assignment

# %%
import pandas as pd
import geopandas as gpd
import psycopg2
import json
from sqlalchemy import create_engine, text
from sqlalchemy.types import Integer, String
from shapely.geometry import shape

# %% [markdown]
# ## Clear data

# %% [markdown]
# Collate the data in "SA2.zip",get the SA2code, SA2name data content and GCC-related information.And filter out the line where the blank information is.Finally, we check whether all the geometry objects in the geometry column are valid and not duplicated.

# %%
SA2 = gpd.read_file("SA2/SA2_2021_AUST_GDA2020.shp")
columns_to_keep = ['SA2_CODE21', 'SA2_NAME21','GCC_CODE21', 'GCC_NAME21', 'geometry']
SA2 = SA2[columns_to_keep]
# Canonical column name
SA2.rename(columns={'SA2_CODE21': 'sa2_code'}, inplace=True)
SA2.rename(columns={'SA2_NAME21': 'sa2_name'}, inplace=True)
SA2.rename(columns={'GCC_CODE21': 'gcc_code'}, inplace=True)
SA2.rename(columns={'GCC_NAME21': 'gcc_name'}, inplace=True)
SA2.dropna(inplace=True)

SA2.drop_duplicates(subset=['geometry'], inplace=True)
valid_geom = SA2['geometry'].apply(lambda x: shape(x).is_valid)
SA2 = SA2[valid_geom]
SA2
# Out:
#        sa2_code                         sa2_name gcc_code  \
# 0     101021007                        Braidwood    1RNSW
# 1     101021008                          Karabar    1RNSW
# 2     101021009                       Queanbeyan    1RNSW
# 3     101021010                Queanbeyan - East    1RNSW
# 4     101021012  Queanbeyan West - Jerrabomberra    1RNSW
# ...         ...                              ...      ...
# 2463  801111141                          Namadgi    8ACTE
# 2466  901011001                 Christmas Island    9OTER
# 2467  901021002          Cocos (Keeling) Islands    9OTER
# 2468  901031003                       Jervis Bay    9OTER
# 2469  901041004                   Norfolk Island    9OTER
#
#                           gcc_name  \
# 0                      Rest of NSW
# 1                      Rest of NSW
# 2                      Rest of NSW
# 3                      Rest of NSW
# 4                      Rest of NSW
# ...                            ...
# 2463  Australian Capital Territory
# 2466             Other Territories
# 2467             Other Territories
# 2468             Other Territories
# 2469             Other Territories
#
#                                                geometry
# 0     POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1     POLYGON ((149.21899 -35.36738, 149.21800 -35.3...
# 2     POLYGON ((149.21326 -35.34325, 149.21619 -35.3...
# 3     POLYGON ((149.24034 -35.34781, 149.24024 -35.3...
# 4     POLYGON ((149.19572 -35.36126, 149.19970 -35.3...
# ...                                                 ...
# 2463  POLYGON ((148.80407 -35.37619, 148.80417 -35.3...
# 2466  POLYGON ((105.67393 -10.41566, 105.67399 -10.4...
# 2467  MULTIPOLYGON (((96.91512 -12.14044, 96.91513 -...
# 2468  MULTIPOLYGON (((150.69567 -35.18295, 150.69556...
# 2469  MULTIPOLYGON (((167.96325 -29.07212, 167.96326...
#
# [2454 rows x 5 columns]

# %% [markdown]
# Collate the data in "Stops.txt",some content that was not relevant for later analysis was deleted, leaving the content related to the platforms in the database and their latitude and longitude data.

# %%
Stops = pd.read_csv("Stops.txt", delimiter=",")
columns_to_keep = ['stop_id','stop_code','stop_name', 'stop_lat','stop_lon']
Stops = Stops[columns_to_keep]
# Canonical column name
Stops.rename(columns={'stop_lat': 'latitude'}, inplace=True)
Stops.rename(columns={'stop_lon': 'longitude'}, inplace=True)

# %% [markdown]
# Collate the data in "Businesses.csv", convert the data content to the corresponding data format,and filtered the data, keeping only data on industry type, sa2 and total number of businesses.And check if the value of SA2 is valid.

# %%
Businesses =  pd.read_csv('Businesses.csv')
Businesses['total_businesses'] = Businesses['total_businesses'].astype(int)
columns_to_keep = ['industry_code','industry_name','sa2_code','sa2_name','total_businesses']
Businesses = Businesses[columns_to_keep]
compare = SA2['sa2_code'].astype(int)
Businesses['match'] = Businesses['sa2_code'].isin(compare)
Businesses = Businesses[Businesses['match'] == True].drop(columns=['match'])

# %% [markdown]
# Collate the data in "PollingPlaces2019.csv",some content that was not relevant for later analysis was removed, and data with blank values and duplicate coordinates are also eliminated.

# %%
Polls = pd.read_csv("PollingPlaces2019.csv")
Polls.drop_duplicates(subset=['the_geom'], inplace=True)
columns_to_keep = ['polling_place_id','polling_place_name','latitude','longitude']
Polls = Polls[columns_to_keep]
Polls.dropna(inplace=True)

# %% [markdown]
# Collate the data in "Catchments.zip", combine the three data information into a data table, in descending order of USE_ID, because in task2, the 0-19 year old people are merged into "young people ", so the" CATCH_TYPE "," ADD_DATE","KINDERGART","YEAR1-12" columns are all removed. Keep only columns for "USE_ID "," USE_DESC","geometry".And filter out the line where the blank information is. Finally, we check whether all the geometry objects in the geometry column are valid and not duplicated.And convert CRS to 7844.

# %%
School_future = gpd.read_file("Catchments/catchments/catchments_future.shp")
School_primary = gpd.read_file("Catchments/catchments/catchments_primary.shp")
School_secondary = gpd.read_file("Catchments/catchments/catchments_secondary.shp")
merged_schools = gpd.GeoDataFrame(pd.concat([School_future, School_primary, School_secondary], ignore_index=True))
columns_to_keep = ['USE_ID','USE_DESC','geometry']
School = merged_schools[columns_to_keep].copy()
School['USE_ID'] = School['USE_ID'].astype(int)
School.dropna(inplace=True)

School.drop_duplicates(subset=['geometry'], inplace=True)
School.drop_duplicates(subset=['USE_ID'], inplace=True)

valid_geom = School['geometry'].apply(lambda x: shape(x).is_valid)
School = School[valid_geom]

School['geometry'] = School['geometry'].to_crs(epsg=7844)

# Canonical column name
School.rename(columns={'USE_ID': 'use_id'}, inplace=True)
School.rename(columns={'USE_DESC': 'use_desc'}, inplace=True)

# %% [markdown]
# Collate the data in "Population.csv", convert the data content to the corresponding data format, and add a column named "young_people" to record young people aged 0-19 in the current region.

# %%
Population = pd.read_csv("Population.csv")

Population['0-4_people'] = Population['0-4_people'].astype(int)
Population['5-9_people'] = Population['5-9_people'].astype(int)
Population['10-14_people'] = Population['10-14_people'].astype(int)
Population['15-19_people'] = Population['15-19_people'].astype(int)

young_people = Population['0-4_people'] + Population['5-9_people'] + Population['10-14_people'] + Population['15-19_people']
Population['young_people'] = young_people

Population['sa2_code'] = Population['sa2_code'].astype(int)
Population['total_people'] = Population['total_people'].astype(int)
columns_to_keep = ['sa2_code','sa2_name','young_people','total_people']
Population = Population[columns_to_keep]

# %% [markdown]
# Collate the data in "incomes.csv", convert the data content into the corresponding data format, clear the abnormal information, and add the column "total_income" to record the total Income in the current region.

# %%
Income = pd.read_csv("Income.csv")

contains_np = Income.apply(lambda row: 'np' in row.values, axis=1)
Income = Income[~contains_np]

Income['earners'] = Income['earners'].astype(int)
Income['mean_income'] = Income['mean_income'].astype(int)
total_income = Income['earners'] * Income['mean_income']
Income['total_income'] = total_income
# Canonical column name
Income.rename(columns={'sa2_code21': 'sa2_code'}, inplace=True)

# %% [markdown]
# ## Import all datasets  PostgreSQL server

# %% [markdown]
# Use the pgconnect function to connect to the PostgreSQL server and load the PostGIS extension.

# %%
def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        port       = db_conn_dict['port']
        try:
            db = create_engine(f'postgresql+psycopg2://{db_user}:{db_pw}@{host}:{port}/{default_db}', echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

# %%
credentials = "Credentials.json"
db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %%
conn.execute("CREATE EXTENSION IF NOT EXISTS postgis;")

# %% [markdown]
# Create the structure of the table, define foreign keys and primary keys to establish associations between different tables.

# %%
# SA2
db.execute('''
CREATE TABLE sa2 (
    sa2_code VARCHAR(255) PRIMARY KEY,
    sa2_name VARCHAR(255),
    GCC_code VARCHAR(255),
    GCC_name VARCHAR(255),
    geometry geometry(MULTIPOLYGON, 7844)
)
''')

# %%
# Stops
db.execute('''
CREATE TABLE stops (
    stop_id VARCHAR(255) PRIMARY KEY,
    stop_code VARCHAR(255),
    stop_name VARCHAR(255),
    latitude FLOAT,
    longitude FLOAT,
    sa2_code VARCHAR(255),
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %%
# Businesses
db.execute('''
CREATE TABLE businesses (
    Industry_code VARCHAR(255),
    industry_name VARCHAR(255),
    sa2_code VARCHAR(255),
    sa2_name VARCHAR(255),
    total_businesses INTEGER,
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %%
# Polls
db.execute('''
CREATE TABLE polls (
    polling_place_id INTEGER PRIMARY KEY,
    polling_place_name VARCHAR(255),
    latitude FLOAT,
    longitude FLOAT,
    sa2_code VARCHAR(255),
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %%
# School
db.execute('''
CREATE TABLE school (
    USE_ID INTEGER PRIMARY KEY,
    USE_DESC VARCHAR(255),
    geometry geometry(MULTIPOLYGON, 7844),
    sa2_code VARCHAR(255),
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %%
# Population
db.execute('''
CREATE TABLE population (
    sa2_code VARCHAR(255),
    sa2_name VARCHAR(255),
    young_people INTEGER,
    total_people INTEGER,
    PRIMARY KEY (sa2_code),
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %%
# Income
db.execute('''
CREATE TABLE income (
    sa2_code VARCHAR(255),
    sa2_name VARCHAR(255),
    earners INTEGER,
    median_age FLOAT,
    median_income FLOAT,
    mean_income FLOAT,
    total_income FLOAT,
    PRIMARY KEY (sa2_code),
    FOREIGN KEY (sa2_code) REFERENCES SA2(sa2_code)
)
''')

# %% [markdown]
# In the Businesses, Population, and Income tables, the SA2_code column is defined as a foreign key, which references the SA2_code column in the SA2 table as the primary key. This establishes an association between these tables.

# %% [markdown]
# Load the cleaned data to the server one by one.

# %%
SA2.to_postgis('sa2', db, index=False,if_exists='append')

# %%
Polls.to_sql('polls', db, index=False, if_exists='append')
# Out:
# 543

# %%
Population.to_sql('population', db, index=False, if_exists='append')
Income.to_sql('income', db, index=False, if_exists='append')
Stops.to_sql('stops', db, index=False, if_exists='append')
Polls.to_sql('polls', db, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:953, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     952     xtras = self._psycopg2_extras()
# --> 953     context._psycopg2_fetched_rows = xtras.execute_values(
#     954         cursor,
#     955         statement,
#     956         parameters,
#     957         template=executemany_values,
#     958         fetch=bool(context.compiled.returning),
#     959         **kwargs
#     960     )
#     962 elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File ~/anaconda3/lib/python3.11/site-packages/psycopg2/extras.py:1299, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298 parts[-1:] = post
# -> 1299 cur.execute(b''.join(parts))
#    1300 if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "polls_pkey"
# DETAIL:  Key (polling_place_id)=(58) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[21], line 4
#       2 Income.to_sql('income', db, index=False, if_exists='append')
#       3 Stops.to_sql('stops', db, index=False, if_exists='append')
# ----> 4 Polls.to_sql('polls', db, index=False, if_exists='append')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                 break
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#    1803     if self.dialect._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:953, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     951         kwargs = {}
#     952     xtras = self._psycopg2_extras()
# --> 953     context._psycopg2_fetched_rows = xtras.execute_values(
#     954         cursor,
#     955         statement,
#     956         parameters,
#     957         template=executemany_values,
#     958         fetch=bool(context.compiled.returning),
#     959         **kwargs
#     960     )
#     962 elif self.executemany_mode & EXECUTEMANY_BATCH:
#     963     if self.executemany_batch_page_size:
#
# File ~/anaconda3/lib/python3.11/site-packages/psycopg2/extras.py:1299, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297     parts.append(b',')
#    1298 parts[-1:] = post
# -> 1299 cur.execute(b''.join(parts))
#    1300 if fetch:
#    1301     result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "polls_pkey"
# DETAIL:  Key (polling_place_id)=(58) already exists.
#
# [SQL: INSERT INTO polls (polling_place_id, polling_place_name, latitude, longitude) VALUES (%(polling_place_id)s, %(polling_place_name)s, %(latitude)s, %(longitude)s)]
# [parameters: ({'polling_place_id': 58, 'polling_place_name': 'Oatley', 'latitude': -33.9847, 'longitude': 151.081}, {'polling_place_id': 392, 'polling_place_name': 'Dharruk', 'latitude': -33.7475, 'longitude': 150.817}, {'polling_place_id': 31, 'polling_place_name': 'Allawah', 'latitude': -33.9767897, 'longitude': 151.1148974}, {'polling_place_id': 67, 'polling_place_name': 'Allawah South', 'latitude': -33.9756, 'longitude': 151.111}, {'polling_place_id': 56500, 'polling_place_name': 'Beverly Hills North (Banks)', 'latitude': -33.9413, 'longitude': 151.075}, {'polling_place_id': 79612, 'polling_place_name': 'Beverly Hills South (Banks)', 'latitude': -33.9528, 'longitude': 151.085}, {'polling_place_id': 46, 'polling_place_name': 'Blakehurst North', 'latitude': -33.9814, 'longitude': 151.113}, {'polling_place_id': 65425, 'polling_place_name': 'BLV Banks PPVC', 'latitude': -33.9674459, 'longitude': 151.1065776}  ... displaying 10 of 2543 total bound parameter sets ...  {'polling_place_id': 31242, 'polling_place_name': 'Welby', 'latitude': -34.4409, 'longitude': 150.424}, {'polling_place_id': 564, 'polling_place_name': 'Windang', 'latitude': -34.5316, 'longitude': 150.866})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
School.to_postgis('school', db, index=False, if_exists='append')

# %%
Businesses.to_sql('businesses', db, index=False, if_exists='append')
# Out:
# 198

# %% [markdown]
# Next, associate SA2_code with SA2 by obtaining the latitude and longitude from Stops, Polls, and School tables.And if sa2 does not match the content, delete the data.

# %%
db.execute('''
ALTER TABLE Stops
ADD COLUMN geom GEOMETRY(Point, 4326);
UPDATE Stops
SET geom = ST_SetSRID(ST_MakePoint(longitude, latitude), 4326);
ALTER TABLE Stops
ADD COLUMN geometry_7844 GEOMETRY(Point, 7844);
UPDATE Stops
SET geometry_7844 = ST_Transform(geom, 7844);

UPDATE Stops s
SET sa2_code = sa2.sa2_code
FROM SA2 sa2
WHERE ST_Within(s.geometry_7844, sa2.geometry);

DELETE FROM Stops
WHERE sa2_code IS NULL;

ALTER TABLE Stops
DROP COLUMN geom;
ALTER TABLE Stops
DROP COLUMN geometry_7844;
''')
# Out:
# ---------------------------------------------------------------------------
# InternalError_                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# InternalError_: transform: File not found or invalid (1029)
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 db.execute('''
#       2 ALTER TABLE Stops
#       3 ADD COLUMN geom GEOMETRY(Point, 4326);
#       4 UPDATE Stops
#       5 SET geom = ST_SetSRID(ST_MakePoint(longitude, latitude), 4326);
#       6 ALTER TABLE Stops
#       7 ADD COLUMN geometry_7844 GEOMETRY(Point, 7844);
#       8 UPDATE Stops
#       9 SET geometry_7844 = ST_Transform(geom, 7844);
#      10
#      11 UPDATE Stops s
#      12 SET sa2_code = sa2.sa2_code
#      13 FROM SA2 sa2
#      14 WHERE ST_Within(s.geometry_7844, sa2.geometry);
#      15
#      16 DELETE FROM Stops
#      17 WHERE sa2_code IS NULL;
#      18
#      19 ALTER TABLE Stops
#      20 DROP COLUMN geom;
#      21 ALTER TABLE Stops
#      22 DROP COLUMN geometry_7844;
#      23 ''')
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# InternalError: (psycopg2.errors.InternalError_) transform: File not found or invalid (1029)
#
# [SQL:
# ALTER TABLE Stops
# ADD COLUMN geom GEOMETRY(Point, 4326);
# UPDATE Stops
# SET geom = ST_SetSRID(ST_MakePoint(longitude, latitude), 4326);
# ALTER TABLE Stops
# ADD COLUMN geometry_7844 GEOMETRY(Point, 7844);
# UPDATE Stops
# SET geometry_7844 = ST_Transform(geom, 7844);
#
# UPDATE Stops s
# SET sa2_code = sa2.sa2_code
# FROM SA2 sa2
# WHERE ST_Within(s.geometry_7844, sa2.geometry);
#
# DELETE FROM Stops
# WHERE sa2_code IS NULL;
#
# ALTER TABLE Stops
# DROP COLUMN geom;
# ALTER TABLE Stops
# DROP COLUMN geometry_7844;
# ]
# (Background on this error at: https://sqlalche.me/e/14/2j85)

# %%
db.execute('''
ALTER TABLE Polls
ADD COLUMN geom GEOMETRY(Point, 4326);
UPDATE Polls
SET geom = ST_SetSRID(ST_MakePoint(longitude, latitude), 4326);
ALTER TABLE Polls
ADD COLUMN geometry_7844 GEOMETRY(Point, 7844);
UPDATE Polls
SET geometry_7844 = ST_Transform(geom, 7844);

UPDATE Polls p
SET sa2_code = sa2.sa2_code
FROM SA2 sa2
WHERE ST_Within(p.geometry_7844, sa2.geometry);

DELETE FROM Polls
WHERE sa2_code IS NULL;

ALTER TABLE Polls
DROP COLUMN geom;
ALTER TABLE Polls
DROP COLUMN geometry_7844;
''')

# %%
db.execute('''
UPDATE School s
SET SA2_code = sa2.SA2_code
FROM SA2 sa2
WHERE ST_Within(s.geometry, sa2.geometry);

DELETE FROM School
WHERE sa2_code IS NULL;
''')

# %% [markdown]
# # Calculate the Zbusiness

# %% [markdown]
# Extract data from database which industries are "Accommodation and Food Services" and "Information Media and Telecommunications". Then calculate the total number of businesses in these industries in each SA2 region. What's more, How busy Accommodation and Food Services are is a direct indicator of how attractive and active an area is, The active degree of Information Media and Telecommunications can reflect the degree of regional technology and information mobility, and is an indicator of the vitality of modern cities.
#
# After that, the z-score formula is given by $z = \frac{X - \mu}{\sigma}$, where $X$ is the value, $\mu$ is the mean, and $\sigma$ is the standard deviation.

# %% [markdown]
# The window function OVER() is used here to calculate the mean and standard deviation of all selected data

# %%
Zbusiness_data = db.execute('''
WITH selected AS(
    SELECT
        sa2_code,
        sa2_name,
        SUM(total_businesses) AS selected_industries
    FROM
        businesses
    WHERE industry_name IN ('Accommodation and Food Services', 'Information Media and Telecommunications')
    GROUP BY 
        sa2_code, 
        sa2_name
)

SELECT
    sa2_code,
    sa2_name,
    (selected_industries - AVG(selected_industries) OVER()) / STDDEV(selected_industries) OVER() AS zbusiness
FROM selected;

''')


for row in Zbusiness_data:
    print(row)
    Zbusiness = row[2]
    print(f"Zbusiness: {Zbusiness}")
# Out:
# ('101021007', 'Braidwood', Decimal('-0.41207323345593395337'))
# Zbusiness: -0.41207323345593395337
# ('101021008', 'Karabar', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('101021009', 'Queanbeyan', Decimal('-0.01362144576703325115'))
# Zbusiness: -0.01362144576703325115
# ('101021010', 'Queanbeyan - East', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('101021012', 'Queanbeyan West - Jerrabomberra', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('101021610', 'Googong', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('101021611', 'Queanbeyan Surrounds', Decimal('-0.09750603264890708319'))
# Zbusiness: -0.09750603264890708319
# ('101031013', 'Bombala', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('101031014', 'Cooma', Decimal('-0.10799160600914131220'))
# Zbusiness: -0.10799160600914131220
# ('101031015', 'Cooma Surrounds', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('101031016', 'Jindabyne - Berridale', Decimal('1.3809598111441192'))
# Zbusiness: 1.3809598111441192
# ('101041017', 'Batemans Bay', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('101041018', 'Batemans Bay - South', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('101041019', 'Bega - Tathra', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('101041020', 'Bega-Eden Hinterland', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('101041021', 'Broulee - Tomakin', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('101041022', 'Deua - Wadbilliga', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('101041023', 'Eden', Decimal('-0.47498667361733932741'))
# Zbusiness: -0.47498667361733932741
# ('101041024', 'Eurobodalla Hinterland', Decimal('-0.53790011377874470144'))
# Zbusiness: -0.53790011377874470144
# ('101041025', 'Merimbula - Tura Beach', Decimal('0.41628706200257013809'))
# Zbusiness: 0.41628706200257013809
# ('101041026', 'Moruya - Tuross Head', Decimal('-0.01362144576703325115'))
# Zbusiness: -0.01362144576703325115
# ('101041027', 'Narooma - Bermagui', Decimal('0.18560444807741709996'))
# Zbusiness: 0.18560444807741709996
# ('101051539', 'Goulburn', Decimal('0.25900346159905670301'))
# Zbusiness: 0.25900346159905670301
# ('101051540', 'Goulburn Surrounds', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('101061541', 'Yass', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('101061542', 'Yass Surrounds', Decimal('-0.17090504617054668623'))
# Zbusiness: -0.17090504617054668623
# ('101061543', 'Young', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('101061544', 'Young Surrounds', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('102011028', 'Avoca Beach - Copacabana', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('102011029', 'Box Head - MacMasters Beach', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('102011030', 'Calga - Kulnura', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('102011031', 'Erina - Green Point', Decimal('0.37434476856163322207'))
# Zbusiness: 0.37434476856163322207
# ('102011032', 'Gosford - Springfield', Decimal('0.72036868944936277926'))
# Zbusiness: 0.72036868944936277926
# ('102011033', 'Kariong', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('102011034', 'Kincumber - Picketts Valley', Decimal('-0.42255880681616818238'))
# Zbusiness: -0.42255880681616818238
# ('102011035', 'Narara', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('102011036', 'Niagara Park - Lisarow', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('102011037', 'Point Clare - Koolewong', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('102011038', 'Saratoga - Davistown', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('102011039', 'Terrigal - North Avoca', Decimal('0.37434476856163322207'))
# Zbusiness: 0.37434476856163322207
# ('102011040', 'Umina - Booker Bay - Patonga', Decimal('0.53162836896514665716'))
# Zbusiness: 0.53162836896514665716
# ('102011041', 'Wamberal - Forresters Beach', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('102011042', 'Woy Woy - Blackwall', Decimal('-0.10799160600914131220'))
# Zbusiness: -0.10799160600914131220
# ('102011043', 'Wyoming', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('102021044', 'Bateau Bay - Killarney Vale', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('102021045', 'Blue Haven - San Remo', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('102021046', 'Budgewoi - Buff Point - Halekulani', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('102021047', 'Chittaway Bay - Tumbi Umbi', Decimal('-0.30721749985359166331'))
# Zbusiness: -0.30721749985359166331
# ('102021048', 'Gorokan - Kanwal - Charmhaven', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('102021049', 'Jilliby - Yarramalong', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('102021050', 'Lake Munmorah - Mannering Park', Decimal('-0.49595782033780778542'))
# Zbusiness: -0.49595782033780778542
# ('102021051', 'Ourimbah - Fountaindale', Decimal('-0.56935683385944738846'))
# Zbusiness: -0.56935683385944738846
# ('102021052', 'Summerland Point - Gwandalan', Decimal('-0.66372699410155544951'))
# Zbusiness: -0.66372699410155544951
# ('102021053', 'The Entrance', Decimal('0.56308508904584934418'))
# Zbusiness: 0.56308508904584934418
# ('102021054', 'Toukley - Norah Head', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('102021055', 'Tuggerah - Kangy Angy', Decimal('-0.20236176625124937325'))
# Zbusiness: -0.20236176625124937325
# ('102021056', 'Warnervale - Wadalba', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('102021057', 'Wyong', Decimal('0.07026314111484058090'))
# Zbusiness: 0.07026314111484058090
# ('103011059', 'Bathurst - East', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('103011060', 'Bathurst Surrounds', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('103011061', 'Oberon', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('103011612', 'Bathurst - South', Decimal('0.36385919520139899306'))
# Zbusiness: 0.36385919520139899306
# ('103011613', 'Bathurst - West', Decimal('-0.40158766009569972436'))
# Zbusiness: -0.40158766009569972436
# ('103021062', 'Condobolin', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('103021063', 'Cowra', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('103021064', 'Cowra Surrounds', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('103021065', 'Forbes', Decimal('-0.31770307321382589232'))
# Zbusiness: -0.31770307321382589232
# ('103021066', 'Grenfell', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('103021067', 'Parkes (NSW)', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('103021068', 'Parkes Surrounds', Decimal('-0.56935683385944738846'))
# Zbusiness: -0.56935683385944738846
# ('103021069', 'West Wyalong', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('103031070', 'Lithgow', Decimal('-0.17090504617054668623'))
# Zbusiness: -0.17090504617054668623
# ('103031071', 'Lithgow Surrounds', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('103031072', 'Mudgee', Decimal('0.17511887471718287096'))
# Zbusiness: 0.17511887471718287096
# ('103031073', 'Mudgee Surrounds - East', Decimal('-0.53790011377874470144'))
# Zbusiness: -0.53790011377874470144
# ('103031074', 'Mudgee Surrounds - West', Decimal('-0.00313587240679902214'))
# Zbusiness: -0.00313587240679902214
# ('103031075', 'Wollangambe - Wollemi', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('103041076', 'Blayney', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('103041077', 'Orange', Decimal('0.75182540953006546628'))
# Zbusiness: 0.75182540953006546628
# ('103041078', 'Orange - North', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('103041079', 'Orange Surrounds', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('104011080', 'Grafton', Decimal('0.22754674151835401599'))
# Zbusiness: 0.22754674151835401599
# ('104011081', 'Grafton Surrounds', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('104011082', 'Maclean - Yamba - Iluka', Decimal('0.51065722224467819915'))
# Zbusiness: 0.51065722224467819915
# ('104021083', 'Bellingen', Decimal('-0.17090504617054668623'))
# Zbusiness: -0.17090504617054668623
# ('104021084', 'Coffs Harbour - North', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('104021085', 'Coffs Harbour - South', Decimal('0.38483034192186745108'))
# Zbusiness: 0.38483034192186745108
# ('104021086', 'Coramba - Nana Glen - Bucca', Decimal('-0.63227027402085276249'))
# Zbusiness: -0.63227027402085276249
# ('104021087', 'Dorrigo', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('104021088', 'Korora - Emerald Beach', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('104021089', 'Sawtell - Boambee', Decimal('0.00734970095343520686'))
# Zbusiness: 0.00734970095343520686
# ('104021090', 'Urunga', Decimal('-0.48547224697757355641'))
# Zbusiness: -0.48547224697757355641
# ('104021091', 'Woolgoolga - Arrawarra', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('105011092', 'Bourke - Brewarrina', Decimal('-0.49595782033780778542'))
# Zbusiness: -0.49595782033780778542
# ('105011093', 'Cobar', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('105011094', 'Coonamble', Decimal('-0.52741454041851047243'))
# Zbusiness: -0.52741454041851047243
# ('105011095', 'Nyngan - Warren', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('105011096', 'Walgett - Lightning Ridge', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('105021097', 'Broken Hill', Decimal('0.15414772799671441295'))
# Zbusiness: 0.15414772799671441295
# ('105021098', 'Far West', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('105031099', 'Coonabarabran', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('105031100', 'Dubbo - East', Decimal('-0.31770307321382589232'))
# Zbusiness: -0.31770307321382589232
# ('105031101', 'Dubbo - South', Decimal('0.64696967592772317622'))
# Zbusiness: 0.64696967592772317622
# ('105031102', 'Dubbo - West', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('105031103', 'Dubbo Surrounds', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('105031104', 'Gilgandra', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('105031105', 'Narromine', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('105031106', 'Wellington', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('106011107', 'Branxton - Greta - Pokolbin', Decimal('0.76231098289029969529'))
# Zbusiness: 0.76231098289029969529
# ('106011108', 'Cessnock', Decimal('-0.13944832608984399922'))
# Zbusiness: -0.13944832608984399922
# ('106011109', 'Cessnock Surrounds', Decimal('-0.43304438017640241138'))
# Zbusiness: -0.43304438017640241138
# ('106011110', 'Dungog', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('106011111', 'Kurri Kurri - Abermain', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('106011112', 'Singleton', Decimal('-0.11847717936937554121'))
# Zbusiness: -0.11847717936937554121
# ('106011113', 'Singleton Surrounds', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('106021114', 'Maitland', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('106021116', 'Maitland - North', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('106021614', 'East Maitland - Metford', Decimal('-0.09750603264890708319'))
# Zbusiness: -0.09750603264890708319
# ('106021615', 'Rutherford (North) - Aberglasslyn', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('106021616', 'Rutherford (South) - Telarah', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('106021617', 'Tenambit - East Maitland', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('106021618', 'Thornton - Millers Forest', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('106031119', 'Anna Bay', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('106031120', 'Lemon Tree Passage - Tanilba Bay', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('106031121', 'Nelson Bay Peninsula', Decimal('0.77279655625053392429'))
# Zbusiness: 0.77279655625053392429
# ('106031122', 'Raymond Terrace', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('106031123', 'Seaham - Woodville', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('106031124', 'Tea Gardens - Hawks Nest', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('106031125', 'Williamtown - Medowie - Karuah', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('106041126', 'Muswellbrook', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('106041127', 'Muswellbrook Surrounds', Decimal('-0.52741454041851047243'))
# Zbusiness: -0.52741454041851047243
# ('106041128', 'Scone', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('106041129', 'Scone Surrounds', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('107011131', 'Dapto - Avondale', Decimal('-0.08702045928867285419'))
# Zbusiness: -0.08702045928867285419
# ('107011132', 'Horsley - Kembla Grange', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('107011133', 'Port Kembla Industrial', Decimal('-0.73712600762319505255'))
# Zbusiness: -0.73712600762319505255
# ('107011134', 'Unanderra - Mount Kembla', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('107011545', 'Berkeley - Lake Heights - Cringila', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('107011546', 'Port Kembla - Warrawong', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('107011547', 'Windang - Primbee', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('107021135', 'Illawarra Catchment Reserve', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('107031136', 'Albion Park - Macquarie Pass', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('107031137', 'Albion Park Rail', Decimal('-0.63227027402085276249'))
# Zbusiness: -0.63227027402085276249
# ('107031138', 'Kiama', Decimal('-0.06604931256820439618'))
# Zbusiness: -0.06604931256820439618
# ('107031139', 'Kiama Downs - Minnamurra', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('107031140', 'Kiama Hinterland - Gerringong', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('107031141', 'Shellharbour - Flinders', Decimal('-0.06604931256820439618'))
# Zbusiness: -0.06604931256820439618
# ('107031142', 'Shellharbour - Oak Flats', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('107031143', 'Warilla', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('107041144', 'Balgownie - Fairy Meadow', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('107041145', 'Corrimal - Tarrawanna - Bellambi', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('107041146', 'Figtree - Keiraville', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('107041147', 'Helensburgh', Decimal('-0.30721749985359166331'))
# Zbusiness: -0.30721749985359166331
# ('107041148', 'Thirroul - Austinmer - Coalcliff', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('107041150', 'Woonona - Bulli - Russell Vale', Decimal('-0.01362144576703325115'))
# Zbusiness: -0.01362144576703325115
# ('107041548', 'Wollongong - East', Decimal('1.8108683189137226'))
# Zbusiness: 1.8108683189137226
# ('107041549', 'Wollongong - West', Decimal('-0.09750603264890708319'))
# Zbusiness: -0.09750603264890708319
# ('108011151', 'Bulahdelah - Stroud', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('108011152', 'Forster', Decimal('0.05977756775460635189'))
# Zbusiness: 0.05977756775460635189
# ('108011153', 'Forster-Tuncurry Surrounds', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('108011154', 'Tuncurry', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('108021155', 'Kempsey', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('108021156', 'Kempsey Surrounds', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('108021157', 'Macksville - Scotts Head', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('108021158', 'Nambucca Heads', Decimal('-0.48547224697757355641'))
# Zbusiness: -0.48547224697757355641
# ('108021159', 'Nambucca Heads Surrounds', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('108021160', 'South West Rocks', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('108031161', 'Lord Howe Island', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('108041162', 'Laurieton - Bonny Hills', Decimal('0.04929199439437212289'))
# Zbusiness: 0.04929199439437212289
# ('108041164', 'Port Macquarie - West', Decimal('0.25900346159905670301'))
# Zbusiness: 0.25900346159905670301
# ('108041165', 'Port Macquarie Surrounds', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('108041166', 'Wauchope', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('108041619', 'Port Macquarie - East', Decimal('0.51065722224467819915'))
# Zbusiness: 0.51065722224467819915
# ('108041620', 'Port Macquarie - South', Decimal('-0.41207323345593395337'))
# Zbusiness: -0.41207323345593395337
# ('108051167', 'Gloucester', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('108051168', 'Old Bar - Manning Point - Red Head', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('108051169', 'Taree', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('108051170', 'Taree Surrounds', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('108051171', 'Wingham', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('109011172', 'Albury - East', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('109011173', 'Albury - North', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('109011174', 'Albury - South', Decimal('0.74133983616983123728'))
# Zbusiness: 0.74133983616983123728
# ('109011175', 'Albury Surrounds', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('109011176', 'Lavington', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('109021177', 'Hay', Decimal('-0.49595782033780778542'))
# Zbusiness: -0.49595782033780778542
# ('109021178', 'Wentworth - Buronga', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('109021179', 'Wentworth-Balranald Region', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('109031180', 'Corowa', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('109031181', 'Corowa Surrounds', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('109031182', 'Deniliquin', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('109031183', 'Deniliquin Surrounds', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('109031184', 'Moama', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('109031185', 'Tocumwal - Finley - Jerilderie', Decimal('-0.09750603264890708319'))
# Zbusiness: -0.09750603264890708319
# ('110011186', 'Armidale', Decimal('0.63648410256748894722'))
# Zbusiness: 0.63648410256748894722
# ('110011187', 'Armidale Surrounds - North', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('110011188', 'Armidale Surrounds - South', Decimal('-0.56935683385944738846'))
# Zbusiness: -0.56935683385944738846
# ('110011189', 'Walcha', Decimal('-0.53790011377874470144'))
# Zbusiness: -0.53790011377874470144
# ('110021190', 'Glen Innes', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('110021191', 'Inverell', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('110021192', 'Inverell Surrounds - East', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('110021193', 'Inverell Surrounds - West', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('110021194', 'Tenterfield', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('110031195', 'Moree', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('110031196', 'Moree Surrounds', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('110031197', 'Narrabri', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('110031198', 'Narrabri Surrounds', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('110041199', 'Gunnedah', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('110041200', 'Gunnedah Surrounds', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('110041201', 'Quirindi', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('110041202', 'Tamworth - East', Decimal('0.05977756775460635189'))
# Zbusiness: 0.05977756775460635189
# ('110041203', 'Tamworth - North', Decimal('0.56308508904584934418'))
# Zbusiness: 0.56308508904584934418
# ('110041204', 'Tamworth - West', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('110041205', 'Tamworth Surrounds', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('111011206', 'Belmont - Bennetts Green', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('111011207', 'Belmont South - Blacksmiths', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('111011208', 'Charlestown - Dudley', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('111011209', 'Glendale - Cardiff - Hillsborough', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('111011210', 'Mount Hutton - Windale', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('111011211', 'Redhead', Decimal('-0.65324142074132122051'))
# Zbusiness: -0.65324142074132122051
# ('111011212', 'Swansea - Caves Beach', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('111011213', 'Valentine - Eleebana', Decimal('-0.51692896705827624343'))
# Zbusiness: -0.51692896705827624343
# ('111011214', 'Warners Bay - Boolaroo', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('111021215', 'Bolton Point - Teralba', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('111021216', 'Bonnells Bay - Silverwater', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('111021217', 'Edgeworth - Cameron Park', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('111021218', 'Morisset - Cooranbong', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('111021219', 'Toronto - Awaba', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('111021220', 'Wangi Wangi - Rathmines', Decimal('-0.54838568713897893045'))
# Zbusiness: -0.54838568713897893045
# ('111021221', 'West Wallsend - Barnsley - Killingworth', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('111031222', 'Adamstown - Kotara', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('111031223', 'Beresfield - Hexham', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('111031224', 'Hamilton - Broadmeadow', Decimal('0.53162836896514665716'))
# Zbusiness: 0.53162836896514665716
# ('111031225', 'Lambton - New Lambton', Decimal('0.01783527431366943587'))
# Zbusiness: 0.01783527431366943587
# ('111031226', 'Maryland - Fletcher - Minmi', Decimal('-0.40158766009569972436'))
# Zbusiness: -0.40158766009569972436
# ('111031227', 'Mayfield - Warabrook', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('111031228', 'Merewether - The Junction', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('111031229', 'Newcastle - Cooks Hill', Decimal('1.7898971721932541'))
# Zbusiness: 1.7898971721932541
# ('111031230', 'Newcastle Port - Kooragang', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('111031231', 'Shortland - Jesmond', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('111031232', 'Stockton - Fullerton Cove', Decimal('-0.49595782033780778542'))
# Zbusiness: -0.49595782033780778542
# ('111031233', 'Wallsend - Elermore Vale', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('111031234', 'Waratah - North Lambton', Decimal('-0.47498667361733932741'))
# Zbusiness: -0.47498667361733932741
# ('111031235', 'Wickham - Carrington - Tighes Hill', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('112011236', 'Ballina', Decimal('0.38483034192186745108'))
# Zbusiness: 0.38483034192186745108
# ('112011237', 'Ballina Surrounds', Decimal('0.00734970095343520686'))
# Zbusiness: 0.00734970095343520686
# ('112011238', 'Bangalow', Decimal('0.10171986119554326792'))
# Zbusiness: 0.10171986119554326792
# ('112011239', 'Brunswick Heads - Ocean Shores', Decimal('0.11220543455577749692'))
# Zbusiness: 0.11220543455577749692
# ('112011240', 'Byron Bay', Decimal('2.2617479734037944'))
# Zbusiness: 2.2617479734037944
# ('112011241', 'Evans Head', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('112011242', 'Lennox Head - Skennars Head', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('112011243', 'Mullumbimby', Decimal('0.21706116815811978698'))
# Zbusiness: 0.21706116815811978698
# ('112021244', 'Casino', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('112021245', 'Casino Surrounds', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('112021246', 'Goonellabah', Decimal('-0.41207323345593395337'))
# Zbusiness: -0.41207323345593395337
# ('112021247', 'Kyogle', Decimal('-0.42255880681616818238'))
# Zbusiness: -0.42255880681616818238
# ('112021248', 'Lismore', Decimal('0.46871492880374128312'))
# Zbusiness: 0.46871492880374128312
# ('112021249', 'Lismore Surrounds', Decimal('-0.01362144576703325115'))
# Zbusiness: -0.01362144576703325115
# ('112031250', 'Kingscliff - Fingal Head', Decimal('0.20657559479788555798'))
# Zbusiness: 0.20657559479788555798
# ('112031251', 'Murwillumbah', Decimal('0.01783527431366943587'))
# Zbusiness: 0.01783527431366943587
# ('112031252', 'Murwillumbah Surrounds', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('112031253', 'Pottsville', Decimal('-0.04507816584773593816'))
# Zbusiness: -0.04507816584773593816
# ('112031254', 'Tweed Heads', Decimal('0.15414772799671441295'))
# Zbusiness: 0.15414772799671441295
# ('112031550', 'Banora Point', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('112031551', 'Terranora - North Tumbulgum', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('112031552', 'Tweed Heads South', Decimal('-0.12896275272960977021'))
# Zbusiness: -0.12896275272960977021
# ('113011256', 'Griffith (NSW)', Decimal('0.32191690176046207704'))
# Zbusiness: 0.32191690176046207704
# ('113011257', 'Griffith Surrounds', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('113011258', 'Leeton', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('113011259', 'Narrandera', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('113021260', 'Tumbarumba', Decimal('-0.52741454041851047243'))
# Zbusiness: -0.52741454041851047243
# ('113021261', 'Tumut', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('113021262', 'Tumut Surrounds', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('113031263', 'Cootamundra', Decimal('-0.43304438017640241138'))
# Zbusiness: -0.43304438017640241138
# ('113031264', 'Gundagai', Decimal('-0.53790011377874470144'))
# Zbusiness: -0.53790011377874470144
# ('113031265', 'Junee', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('113031266', 'Temora', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('113031267', 'Wagga Wagga - East', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('113031268', 'Wagga Wagga - North', Decimal('-0.63227027402085276249'))
# Zbusiness: -0.63227027402085276249
# ('113031269', 'Wagga Wagga - South', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('113031270', 'Wagga Wagga - West', Decimal('0.74133983616983123728'))
# Zbusiness: 0.74133983616983123728
# ('113031271', 'Wagga Wagga Surrounds', Decimal('-0.10799160600914131220'))
# Zbusiness: -0.10799160600914131220
# ('114011272', 'Berry - Kangaroo Valley', Decimal('0.33240247512069630605'))
# Zbusiness: 0.33240247512069630605
# ('114011273', 'Callala Bay - Currarong', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('114011274', 'Culburra Beach', Decimal('-0.42255880681616818238'))
# Zbusiness: -0.42255880681616818238
# ('114011275', 'Ettrema - Sassafras - Budawang', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('114011276', 'Huskisson - Vincentia', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('114011277', 'North Nowra - Bomaderry', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('114011278', 'Nowra', Decimal('0.35337362184116476406'))
# Zbusiness: 0.35337362184116476406
# ('114011279', 'St Georges Basin - Erowal Bay', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('114011280', 'Sussex Inlet - Berrara', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('114011281', 'Tomerong - Wandandian - Woollamia', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('114011282', 'Ulladulla', Decimal('0.50017164888444397014'))
# Zbusiness: 0.50017164888444397014
# ('114011283', 'Ulladulla Surrounds', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('114021284', 'Bowral', Decimal('0.61551295584702048921'))
# Zbusiness: 0.61551295584702048921
# ('114021285', 'Hill Top - Colo Vale', Decimal('-0.66372699410155544951'))
# Zbusiness: -0.66372699410155544951
# ('114021286', 'Mittagong', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('114021287', 'Moss Vale - Berrima', Decimal('-0.06604931256820439618'))
# Zbusiness: -0.06604931256820439618
# ('114021288', 'Robertson - Fitzroy Falls', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('114021289', 'Southern Highlands', Decimal('-0.12896275272960977021'))
# Zbusiness: -0.12896275272960977021
# ('115011290', 'Baulkham Hills - East', Decimal('0.08074871447507480991'))
# Zbusiness: 0.08074871447507480991
# ('115011291', 'Baulkham Hills (West) - Bella Vista', Decimal('1.9262096258762991'))
# Zbusiness: 1.9262096258762991
# ('115011294', 'Glenhaven', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('115011296', 'West Pennant Hills', Decimal('-0.17090504617054668623'))
# Zbusiness: -0.17090504617054668623
# ('115011553', 'Castle Hill - Central', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('115011554', 'Castle Hill - East', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('115011555', 'Castle Hill - North', Decimal('-0.06604931256820439618'))
# Zbusiness: -0.06604931256820439618
# ('115011556', 'Castle Hill - South', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('115011557', 'Castle Hill - West', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('115011558', 'Cherrybrook', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('115011621', 'Kellyville - East', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('115011622', 'Kellyville - West', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('115021297', 'Dural - Kenthurst - Wisemans Ferry', Decimal('0.82522442305170506932'))
# Zbusiness: 0.82522442305170506932
# ('115021298', 'Galston - Laughtondale', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('115031299', 'Bilpin - Colo - St Albans', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('115031300', 'Kurrajong Heights - Ebenezer', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('115041301', 'Pitt Town - McGraths Hill', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('115041623', 'Box Hill - Nelson', Decimal('-0.52741454041851047243'))
# Zbusiness: -0.52741454041851047243
# ('115041624', 'North Kellyville', Decimal('-0.00313587240679902214'))
# Zbusiness: -0.00313587240679902214
# ('115041625', 'Rouse Hill - Beaumont Hills', Decimal('0.10171986119554326792'))
# Zbusiness: 0.10171986119554326792
# ('116011303', 'Blacktown (East) - Kings Park', Decimal('0.58405623576631780219'))
# Zbusiness: 0.58405623576631780219
# ('116011304', 'Blacktown (North) - Marayong', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('116011306', 'Doonside - Woodcroft', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('116011307', 'Lalor Park - Kings Langley', Decimal('0.17511887471718287096'))
# Zbusiness: 0.17511887471718287096
# ('116011560', 'Blacktown - South', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('116011561', 'Blacktown - West', Decimal('0.03880642103413789388'))
# Zbusiness: 0.03880642103413789388
# ('116011626', 'Seven Hills - Prospect', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('116011627', 'Toongabbie - West', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('116021309', 'Glenwood', Decimal('-0.08702045928867285419'))
# Zbusiness: -0.08702045928867285419
# ('116021562', 'Acacia Gardens', Decimal('-0.68469814082202390752'))
# Zbusiness: -0.68469814082202390752
# ('116021563', 'Quakers Hill', Decimal('-0.11847717936937554121'))
# Zbusiness: -0.11847717936937554121
# ('116021628', 'Kellyville Ridge - The Ponds', Decimal('0.15414772799671441295'))
# Zbusiness: 0.15414772799671441295
# ('116021629', 'Marsden Park - Shanes Park', Decimal('-0.04507816584773593816'))
# Zbusiness: -0.04507816584773593816
# ('116021630', 'Riverstone', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('116021631', 'Schofields (West) - Colebee', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('116021632', 'Schofields - East', Decimal('0.10171986119554326792'))
# Zbusiness: 0.10171986119554326792
# ('116021633', 'Stanhope Gardens - Parklea', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('116031313', 'Bidwill - Hebersham - Emerton', Decimal('-0.41207323345593395337'))
# Zbusiness: -0.41207323345593395337
# ('116031314', 'Glendenning - Dean Park', Decimal('-0.53790011377874470144'))
# Zbusiness: -0.53790011377874470144
# ('116031315', 'Hassall Grove - Plumpton', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('116031316', 'Lethbridge Park - Tregear', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('116031317', 'Mount Druitt - Whalan', Decimal('0.12269100791601172593'))
# Zbusiness: 0.12269100791601172593
# ('116031318', 'Prospect Reservoir', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('116031319', 'Rooty Hill - Minchinbury', Decimal('0.15414772799671441295'))
# Zbusiness: 0.15414772799671441295
# ('117011320', 'Banksmeadow', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('117011321', 'Botany', Decimal('0.17511887471718287096'))
# Zbusiness: 0.17511887471718287096
# ('117011323', 'Pagewood - Hillsdale - Daceyville', Decimal('0.01783527431366943587'))
# Zbusiness: 0.01783527431366943587
# ('117011324', 'Port Botany Industrial', Decimal('-0.73712600762319505255'))
# Zbusiness: -0.73712600762319505255
# ('117011325', 'Sydney Airport', Decimal('-0.73712600762319505255'))
# Zbusiness: -0.73712600762319505255
# ('117011634', 'Eastlakes', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('117011635', 'Mascot', Decimal('0.96153687673475004640'))
# Zbusiness: 0.96153687673475004640
# ('117021327', 'Petersham - Stanmore', Decimal('1.7794115988330199'))
# Zbusiness: 1.7794115988330199
# ('117021328', 'Sydenham - Tempe - St Peters', Decimal('0.21706116815811978698'))
# Zbusiness: 0.21706116815811978698
# ('117021636', 'Marrickville - North', Decimal('1.0978493304177950'))
# Zbusiness: 1.0978493304177950
# ('117021637', 'Marrickville - South', Decimal('0.46871492880374128312'))
# Zbusiness: 0.46871492880374128312
# ('117031329', 'Darlinghurst', Decimal('2.0100942127581729'))
# Zbusiness: 2.0100942127581729
# ('117031330', 'Erskineville - Alexandria', Decimal('2.3770892803663710'))
# Zbusiness: 2.3770892803663710
# ('117031331', 'Glebe - Forest Lodge', Decimal('1.6850414385909118'))
# Zbusiness: 1.6850414385909118
# ('117031333', 'Potts Point - Woolloomooloo', Decimal('2.4190315738073079'))
# Zbusiness: 2.4190315738073079
# ('117031336', 'Surry Hills', Decimal('5.4703334216354685'))
# Zbusiness: 5.4703334216354685
# ('117031638', 'Camperdown - Darlington', Decimal('0.00734970095343520686'))
# Zbusiness: 0.00734970095343520686
# ('117031639', 'Chippendale', Decimal('0.98250802345521850441'))
# Zbusiness: 0.98250802345521850441
# ('117031640', 'Newtown (NSW)', Decimal('1.6430991451499749'))
# Zbusiness: 1.6430991451499749
# ('117031641', 'Pyrmont', Decimal('1.3809598111441192'))
# Zbusiness: 1.3809598111441192
# ('117031642', 'Redfern', Decimal('1.5277578381873984'))
# Zbusiness: 1.5277578381873984
# ('117031643', 'Rosebery - Beaconsfield', Decimal('0.62599852920725471821'))
# Zbusiness: 0.62599852920725471821
# ('117031644', 'Sydney (North) - Millers Point', Decimal('18.3990453748042729'))
# Zbusiness: 18.3990453748042729
# ('117031645', 'Sydney (South) - Haymarket', Decimal('7.1689963059934136'))
# Zbusiness: 7.1689963059934136
# ('117031646', 'Ultimo', Decimal('0.85668114313240775634'))
# Zbusiness: 0.85668114313240775634
# ('117031647', 'Waterloo', Decimal('0.88813786321311044336'))
# Zbusiness: 0.88813786321311044336
# ('117031648', 'Zetland', Decimal('0.45822935544350705412'))
# Zbusiness: 0.45822935544350705412
# ('118011339', 'Bondi - Tamarama - Bronte', Decimal('1.3495030910634165'))
# Zbusiness: 1.3495030910634165
# ('118011340', 'Bondi Beach - North Bondi', Decimal('2.3456325602856683'))
# Zbusiness: 2.3456325602856683
# ('118011341', 'Bondi Junction - Waverly', Decimal('2.0100942127581729'))
# Zbusiness: 2.0100942127581729
# ('118011342', 'Centennial Park', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('118011344', 'Dover Heights', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('118011345', 'Paddington - Moore Park', Decimal('2.1359210930809837'))
# Zbusiness: 2.1359210930809837
# ('118011346', 'Rose Bay - Vaucluse - Watsons Bay', Decimal('0.62599852920725471821'))
# Zbusiness: 0.62599852920725471821
# ('118011347', 'Woollahra', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('118011649', 'Bellevue Hill', Decimal('0.38483034192186745108'))
# Zbusiness: 0.38483034192186745108
# ('118011650', 'Double Bay - Darling Point', Decimal('1.0139647435359212'))
# Zbusiness: 1.0139647435359212
# ('118021564', 'Kensington (NSW)', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('118021565', 'Kingsford', Decimal('0.22754674151835401599'))
# Zbusiness: 0.22754674151835401599
# ('118021566', 'Maroubra - North', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('118021567', 'Maroubra - South', Decimal('-0.12896275272960977021'))
# Zbusiness: -0.12896275272960977021
# ('118021568', 'Maroubra - West', Decimal('0.04929199439437212289'))
# Zbusiness: 0.04929199439437212289
# ('118021569', 'Randwick - North', Decimal('0.29046018167975939002'))
# Zbusiness: 0.29046018167975939002
# ('118021570', 'Randwick - South', Decimal('0.52114279560491242815'))
# Zbusiness: 0.52114279560491242815
# ('118021651', 'Coogee - Clovelly', Decimal('0.95105130337451581739'))
# Zbusiness: 0.95105130337451581739
# ('118021652', 'Malabar - La Perouse', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('118021653', 'Matraville - Chifley', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('118021654', 'South Coogee', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('119011354', 'Bass Hill - Georges Hall', Decimal('0.48968607552420974114'))
# Zbusiness: 0.48968607552420974114
# ('119011355', 'Chullora', Decimal('-0.48547224697757355641'))
# Zbusiness: -0.48547224697757355641
# ('119011356', 'Condell Park', Decimal('-0.00313587240679902214'))
# Zbusiness: -0.00313587240679902214
# ('119011358', 'Padstow', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('119011360', 'Revesby', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('119011361', 'Yagoona - Birrong', Decimal('0.00734970095343520686'))
# Zbusiness: 0.00734970095343520686
# ('119011571', 'Bankstown - North', Decimal('0.43725820872303859611'))
# Zbusiness: 0.43725820872303859611
# ('119011572', 'Bankstown - South', Decimal('0.62599852920725471821'))
# Zbusiness: 0.62599852920725471821
# ('119011655', 'Greenacre - North', Decimal('-0.04507816584773593816'))
# Zbusiness: -0.04507816584773593816
# ('119011656', 'Greenacre - South', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('119011657', 'Panania (North) - Milperra', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('119011658', 'Panania (South) - Picnic Point', Decimal('-0.18139061953078091524'))
# Zbusiness: -0.18139061953078091524
# ('119021362', 'Belmore - Belfield', Decimal('0.25900346159905670301'))
# Zbusiness: 0.25900346159905670301
# ('119021366', 'Punchbowl', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('119021367', 'Roselands', Decimal('-0.08702045928867285419'))
# Zbusiness: -0.08702045928867285419
# ('119021573', 'Lakemba', Decimal('1.0454214636166239'))
# Zbusiness: 1.0454214636166239
# ('119021574', 'Wiley Park', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('119021659', 'Campsie - North', Decimal('-0.11847717936937554121'))
# Zbusiness: -0.11847717936937554121
# ('119021660', 'Campsie - South', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('119021661', 'Canterbury - South', Decimal('-0.20236176625124937325'))
# Zbusiness: -0.20236176625124937325
# ('119021662', 'Earlwood', Decimal('0.33240247512069630605'))
# Zbusiness: 0.33240247512069630605
# ('119021663', 'Kingsgrove - North', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('119031370', 'Narwee - Beverly Hills', Decimal('-0.04507816584773593816'))
# Zbusiness: -0.04507816584773593816
# ('119031371', 'Oatley - Hurstville Grove', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('119031372', 'Peakhurst - Lugarno', Decimal('0.03880642103413789388'))
# Zbusiness: 0.03880642103413789388
# ('119031373', 'Riverwood', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('119031374', 'South Hurstville - Blakehurst', Decimal('0.42677263536280436710'))
# Zbusiness: 0.42677263536280436710
# ('119031664', 'Hurstville - Central', Decimal('0.88813786321311044336'))
# Zbusiness: 0.88813786321311044336
# ('119031665', 'Hurstville - North', Decimal('-0.23381848633195206027'))
# Zbusiness: -0.23381848633195206027
# ('119031666', 'Mortdale - Oatley', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('119031667', 'Penshurst', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('119041377', 'Kingsgrove (South) - Bardwell Park', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('119041378', 'Kogarah', Decimal('0.30094575503999361903'))
# Zbusiness: 0.30094575503999361903
# ('119041379', 'Kogarah Bay - Carlton - Allawah', Decimal('-0.08702045928867285419'))
# Zbusiness: -0.08702045928867285419
# ('119041380', 'Monterey - Brighton-le-Sands - Kyeemagh', Decimal('0.35337362184116476406'))
# Zbusiness: 0.35337362184116476406
# ('119041381', 'Rockdale - Banksia', Decimal('0.93008015665404735938'))
# Zbusiness: 0.93008015665404735938
# ('119041382', 'Sans Souci - Ramsgate', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('119041668', 'Arncliffe - Bardwell Valley', Decimal('0.13317658127624595494'))
# Zbusiness: 0.13317658127624595494
# ('119041669', 'Bexley - North', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('119041670', 'Bexley - South', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('119041671', 'Wolli Creek', Decimal('-0.13944832608984399922'))
# Zbusiness: -0.13944832608984399922
# ('120011383', 'Concord - Mortlake - Cabarita', Decimal('0.91959458329381313038'))
# Zbusiness: 0.91959458329381313038
# ('120011385', 'Drummoyne - Rodd Point', Decimal('0.61551295584702048921'))
# Zbusiness: 0.61551295584702048921
# ('120011386', 'Five Dock - Abbotsford', Decimal('0.62599852920725471821'))
# Zbusiness: 0.62599852920725471821
# ('120011672', 'Concord West - North Strathfield', Decimal('0.19609002143765132897'))
# Zbusiness: 0.19609002143765132897
# ('120011673', 'Rhodes', Decimal('0.79376770297100238231'))
# Zbusiness: 0.79376770297100238231
# ('120021387', 'Balmain', Decimal('1.3495030910634165'))
# Zbusiness: 1.3495030910634165
# ('120021389', 'Lilyfield - Rozelle', Decimal('0.66794082264819163424'))
# Zbusiness: 0.66794082264819163424
# ('120021674', 'Annandale (NSW)', Decimal('0.32191690176046207704'))
# Zbusiness: 0.32191690176046207704
# ('120021675', 'Leichhardt', Decimal('1.5382434115476326'))
# Zbusiness: 1.5382434115476326
# ('120031392', 'Canterbury (North) - Ashbury', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('120031393', 'Croydon Park - Enfield', Decimal('0.16463330135694864195'))
# Zbusiness: 0.16463330135694864195
# ('120031394', 'Dulwich Hill - Lewisham', Decimal('0.12269100791601172593'))
# Zbusiness: 0.12269100791601172593
# ('120031395', 'Haberfield - Summer Hill', Decimal('0.32191690176046207704'))
# Zbusiness: 0.32191690176046207704
# ('120031396', 'Homebush', Decimal('0.74133983616983123728'))
# Zbusiness: 0.74133983616983123728
# ('120031576', 'Strathfield South', Decimal('-0.57984240721968161746'))
# Zbusiness: -0.57984240721968161746
# ('120031676', 'Ashfield - North', Decimal('-0.25478963305242051828'))
# Zbusiness: -0.25478963305242051828
# ('120031677', 'Ashfield - South', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('120031678', 'Burwood (NSW)', Decimal('1.5906712783488038'))
# Zbusiness: 1.5906712783488038
# ('120031679', 'Croydon', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('120031680', 'Strathfield - East', Decimal('0.77279655625053392429'))
# Zbusiness: 0.77279655625053392429
# ('120031681', 'Strathfield - West', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('121011399', 'Chatswood (West) - Lane Cove North', Decimal('0.25900346159905670301'))
# Zbusiness: 0.25900346159905670301
# ('121011401', 'St Leonards - Naremburn', Decimal('1.6326135717897407'))
# ...
# Zbusiness: -0.33867421993429435033
# ('122031695', 'Dee Why - North', Decimal('0.59454180912655203119'))
# Zbusiness: 0.59454180912655203119
# ('122031696', 'Frenchs Forest - Oxford Falls', Decimal('0.19609002143765132897'))
# Zbusiness: 0.19609002143765132897
# ('122031697', 'Narrabeen - Wheeler Heights', Decimal('-0.11847717936937554121'))
# Zbusiness: -0.11847717936937554121
# ('123011433', 'Camden - Ellis Lane', Decimal('-0.04507816584773593816'))
# Zbusiness: -0.04507816584773593816
# ('123011698', 'Currans Hill', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('123011699', 'Elderslie - Narellan', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('123011700', 'Harrington Park', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('123011701', 'Mount Annan', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('123011702', 'Spring Farm', Decimal('-0.65324142074132122051'))
# Zbusiness: -0.65324142074132122051
# ('123021436', 'Bradbury - Wedderburn', Decimal('-0.47498667361733932741'))
# Zbusiness: -0.47498667361733932741
# ('123021437', 'Campbelltown - Woodbine', Decimal('0.76231098289029969529'))
# Zbusiness: 0.76231098289029969529
# ('123021438', 'Claymore - Eagle Vale - Raby', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('123021439', 'Holsworthy Military Area', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('123021441', 'Leumeah - Minto Heights', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('123021443', 'Minto - St Andrews', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('123021444', 'Rosemeadow - Glen Alpine', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('123021703', 'Denham Court - Bardia', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('123021704', 'Glenfield', Decimal('-0.54838568713897893045'))
# Zbusiness: -0.54838568713897893045
# ('123021705', 'Ingleburn', Decimal('0.04929199439437212289'))
# Zbusiness: 0.04929199439437212289
# ('123021706', 'Macquarie Fields', Decimal('-0.42255880681616818238'))
# Zbusiness: -0.42255880681616818238
# ('123031445', 'Bargo', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('123031446', 'Douglas Park - Appin', Decimal('-0.40158766009569972436'))
# Zbusiness: -0.40158766009569972436
# ('123031447', 'Picton - Tahmoor - Buxton', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('123031448', 'The Oaks - Oakdale', Decimal('-0.63227027402085276249'))
# Zbusiness: -0.63227027402085276249
# ('124011449', 'Blackheath - Megalong Valley', Decimal('-0.17090504617054668623'))
# Zbusiness: -0.17090504617054668623
# ('124011450', 'Blaxland - Warrimoo - Lapstone', Decimal('-0.09750603264890708319'))
# Zbusiness: -0.09750603264890708319
# ('124011451', 'Blue Mountains - North', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('124011452', 'Katoomba - Leura', Decimal('0.87765228985287621435'))
# Zbusiness: 0.87765228985287621435
# ('124011453', 'Lawson - Hazelbrook - Linden', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('124011454', 'Springwood - Winmalee', Decimal('0.08074871447507480991'))
# Zbusiness: 0.08074871447507480991
# ('124011455', 'Wentworth Falls', Decimal('-0.31770307321382589232'))
# Zbusiness: -0.31770307321382589232
# ('124021456', 'Blue Mountains - South', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('124031457', 'Cambridge Park', Decimal('-0.52741454041851047243'))
# Zbusiness: -0.52741454041851047243
# ('124031459', 'Emu Plains - Leonay', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('124031460', 'Glenmore Park - Regentville', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('124031461', 'Jamisontown - South Penrith', Decimal('-0.11847717936937554121'))
# Zbusiness: -0.11847717936937554121
# ('124031462', 'Kingswood - Werrington', Decimal('-0.00313587240679902214'))
# Zbusiness: -0.00313587240679902214
# ('124031463', 'Mulgoa - Luddenham - Orchard Hills', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('124031464', 'Penrith', Decimal('0.80425327633123661131'))
# Zbusiness: 0.80425327633123661131
# ('124031465', 'Warragamba - Silverdale', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('124031707', 'Cranebrook - Castlereagh', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('124031708', 'Jordan Springs - Llandilo', Decimal('-0.42255880681616818238'))
# Zbusiness: -0.42255880681616818238
# ('124041466', 'Richmond - Clarendon', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('124041467', 'Windsor - Bligh Park', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('124041468', 'Yarramundi - Londonderry', Decimal('-0.59032798057991584647'))
# Zbusiness: -0.59032798057991584647
# ('124051469', 'Erskine Park', Decimal('-0.65324142074132122051'))
# Zbusiness: -0.65324142074132122051
# ('124051470', 'St Clair', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('124051580', 'Colyton - Oxley Park', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('124051581', 'St Marys - North St Marys', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('125011475', 'Rookwood Cemetery', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('125011582', 'Auburn - Central', Decimal('0.43725820872303859611'))
# Zbusiness: 0.43725820872303859611
# ('125011583', 'Auburn - North', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('125011584', 'Auburn - South', Decimal('-0.29673192649335743431'))
# Zbusiness: -0.29673192649335743431
# ('125011585', 'Berala', Decimal('-0.45401552689687086939'))
# Zbusiness: -0.45401552689687086939
# ('125011586', 'Lidcombe', Decimal('1.2027050640201373'))
# Zbusiness: 1.2027050640201373
# ('125011587', 'Regents Park', Decimal('-0.49595782033780778542'))
# Zbusiness: -0.49595782033780778542
# ('125011709', 'Silverwater - Newington', Decimal('0.39531591528210168008'))
# Zbusiness: 0.39531591528210168008
# ('125011710', 'Wentworth Point - Sydney Olympic Park', Decimal('0.88813786321311044336'))
# Zbusiness: 0.88813786321311044336
# ('125021477', 'Ermington - Rydalmere', Decimal('0.62599852920725471821'))
# Zbusiness: 0.62599852920725471821
# ('125021478', 'Oatlands - Dundas Valley', Decimal('-0.12896275272960977021'))
# Zbusiness: -0.12896275272960977021
# ('125021711', 'Carlingford - East', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('125021712', 'Carlingford - West', Decimal('0.22754674151835401599'))
# Zbusiness: 0.22754674151835401599
# ('125031479', 'Chester Hill - Sefton', Decimal('0.23803231487858824499'))
# Zbusiness: 0.23803231487858824499
# ('125031480', 'Fairfield - East', Decimal('-0.22333291297171783126'))
# Zbusiness: -0.22333291297171783126
# ('125031481', 'Granville - Clyde', Decimal('0.35337362184116476406'))
# Zbusiness: 0.35337362184116476406
# ('125031483', 'Guildford - South Granville', Decimal('0.31143132840022784804'))
# Zbusiness: 0.31143132840022784804
# ('125031484', 'Guildford West - Merrylands West', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('125031486', 'Smithfield Industrial', Decimal('-0.61129912730038430448'))
# Zbusiness: -0.61129912730038430448
# ('125031487', 'Yennora Industrial', Decimal('-0.72664043426296082355'))
# Zbusiness: -0.72664043426296082355
# ('125031713', 'Greystanes - South', Decimal('-0.19187619289101514425'))
# Zbusiness: -0.19187619289101514425
# ('125031714', 'Merrylands - Holroyd', Decimal('0.53162836896514665716'))
# Zbusiness: 0.53162836896514665716
# ('125031715', 'Pemulwuy - Greystanes (North)', Decimal('-0.35964536665476280834'))
# Zbusiness: -0.35964536665476280834
# ('125031716', 'South Wentworthville', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('125041489', 'North Parramatta', Decimal('0.30094575503999361903'))
# Zbusiness: 0.30094575503999361903
# ('125041490', 'North Rocks', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('125041491', 'Northmead', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('125041493', 'Toongabbie - Constitution Hill', Decimal('0.09123428783530903891'))
# Zbusiness: 0.09123428783530903891
# ('125041494', 'Winston Hills', Decimal('-0.31770307321382589232'))
# Zbusiness: -0.31770307321382589232
# ('125041588', 'Pendle Hill - Girraween', Decimal('-0.02410701912726748015'))
# Zbusiness: -0.02410701912726748015
# ('125041589', 'Wentworthville - Westmead', Decimal('0.37434476856163322207'))
# Zbusiness: 0.37434476856163322207
# ('125041717', 'Parramatta - North', Decimal('1.9891230660377045'))
# Zbusiness: 1.9891230660377045
# ('125041718', 'Parramatta - South', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('125041719', 'Rosehill - Harris Park', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('126011496', 'Pennant Hills - Cheltenham', Decimal('0.51065722224467819915'))
# Zbusiness: 0.51065722224467819915
# ('126011720', 'Epping (East) - North Epping', Decimal('-0.03459259248750170916'))
# Zbusiness: -0.03459259248750170916
# ('126011721', 'Epping (NSW) - West', Decimal('0.24851788823882247400'))
# Zbusiness: 0.24851788823882247400
# ('126021498', 'Gladesville - Huntleys Point', Decimal('0.35337362184116476406'))
# Zbusiness: 0.35337362184116476406
# ('126021499', 'Hunters Hill - Woolwich', Decimal('0.20657559479788555798'))
# Zbusiness: 0.20657559479788555798
# ('126021500', 'Macquarie Park - Marsfield', Decimal('0.94056573001428158839'))
# Zbusiness: 0.94056573001428158839
# ('126021501', 'North Ryde - East Ryde', Decimal('0.13317658127624595494'))
# Zbusiness: 0.13317658127624595494
# ('126021503', 'West Ryde - Meadowbank', Decimal('0.42677263536280436710'))
# Zbusiness: 0.42677263536280436710
# ('126021590', 'Putney', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('126021722', 'Denistone', Decimal('-0.50644339369804201442'))
# Zbusiness: -0.50644339369804201442
# ('126021723', 'Eastwood', Decimal('1.3285319443429481'))
# Zbusiness: 1.3285319443429481
# ('126021724', 'Ryde - North', Decimal('0.46871492880374128312'))
# Zbusiness: 0.46871492880374128312
# ('126021725', 'Ryde - South', Decimal('-0.14993389945007822822'))
# Zbusiness: -0.14993389945007822822
# ('127011504', 'Ashcroft - Busby - Miller', Decimal('-0.40158766009569972436'))
# Zbusiness: -0.40158766009569972436
# ('127011505', 'Austral - Greendale', Decimal('-0.33867421993429435033'))
# Zbusiness: -0.33867421993429435033
# ('127011592', 'Badgerys Creek', Decimal('-0.76858272770389773957'))
# Zbusiness: -0.76858272770389773957
# ('127011593', 'Cecil Hills', Decimal('-0.47498667361733932741'))
# Zbusiness: -0.47498667361733932741
# ('127011594', 'Green Valley', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('127011595', 'Hinchinbrook', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('127011596', 'Hoxton Park - Carnes Hill - Horningsea Park', Decimal('-0.24430405969218628928'))
# Zbusiness: -0.24430405969218628928
# ('127011597', 'West Hoxton - Middleton Grange', Decimal('-0.20236176625124937325'))
# Zbusiness: -0.20236176625124937325
# ('127011726', 'Cobbitty - Bringelly', Decimal('-0.64275584738108699150'))
# Zbusiness: -0.64275584738108699150
# ('127011727', 'Gledswood Hills - Gregory Hills', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('127011728', 'Leppington - Catherine Field', Decimal('-0.30721749985359166331'))
# Zbusiness: -0.30721749985359166331
# ('127011729', 'Oran Park', Decimal('-0.27576077977288897629'))
# Zbusiness: -0.27576077977288897629
# ('127021509', 'Bonnyrigg Heights - Bonnyrigg', Decimal('-0.16041947281031245723'))
# Zbusiness: -0.16041947281031245723
# ('127021510', 'Bossley Park - Abbotsbury', Decimal('-0.20236176625124937325'))
# Zbusiness: -0.20236176625124937325
# ('127021511', 'Cabramatta - Lansvale', Decimal('1.0559070369768581'))
# Zbusiness: 1.0559070369768581
# ('127021512', 'Cabramatta West - Mount Pritchard', Decimal('-0.05556373920797016717'))
# Zbusiness: -0.05556373920797016717
# ('127021513', 'Canley Vale - Canley Heights', Decimal('0.21706116815811978698'))
# Zbusiness: 0.21706116815811978698
# ('127021514', 'Edensor Park', Decimal('-0.20236176625124937325'))
# Zbusiness: -0.20236176625124937325
# ('127021515', 'Fairfield', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('127021516', 'Fairfield - West', Decimal('-0.10799160600914131220'))
# Zbusiness: -0.10799160600914131220
# ('127021517', 'Greenfield Park - Prairiewood', Decimal('-0.37013094001499703735'))
# Zbusiness: -0.37013094001499703735
# ('127021518', 'Horsley Park - Kemps Creek', Decimal('-0.48547224697757355641'))
# Zbusiness: -0.48547224697757355641
# ('127021519', 'Smithfield - Wetherill Park', Decimal('-0.10799160600914131220'))
# Zbusiness: -0.10799160600914131220
# ('127021520', 'St Johns Park - Wakeley', Decimal('-0.46450110025710509840'))
# Zbusiness: -0.46450110025710509840
# ('127021521', 'Wetherill Park Industrial', Decimal('-0.32818864657406012132'))
# Zbusiness: -0.32818864657406012132
# ('127031522', 'Casula', Decimal('-0.28624635313312320530'))
# Zbusiness: -0.28624635313312320530
# ('127031523', 'Chipping Norton - Moorebank', Decimal('0.61551295584702048921'))
# Zbusiness: 0.61551295584702048921
# ('127031524', 'Holsworthy - Wattle Grove', Decimal('-0.07653488592843862518'))
# Zbusiness: -0.07653488592843862518
# ('127031599', 'Lurnea - Cartwright', Decimal('-0.55887126049921315945'))
# Zbusiness: -0.55887126049921315945
# ('127031601', 'Warwick Farm', Decimal('-0.62178470066061853349'))
# Zbusiness: -0.62178470066061853349
# ('127031730', 'Edmondson Park', Decimal('-0.44352995353663664039'))
# Zbusiness: -0.44352995353663664039
# ('127031731', 'Liverpool - East', Decimal('0.37434476856163322207'))
# Zbusiness: 0.37434476856163322207
# ('127031732', 'Liverpool - West', Decimal('-0.34915979329452857933'))
# Zbusiness: -0.34915979329452857933
# ('127031733', 'Prestons', Decimal('0.02832084767390366488'))
# Zbusiness: 0.02832084767390366488
# ('128011529', 'Gymea - Grays Point', Decimal('-0.21284733961148360226'))
# Zbusiness: -0.21284733961148360226
# ('128011530', 'Miranda - Yowie Bay', Decimal('0.31143132840022784804'))
# Zbusiness: 0.31143132840022784804
# ('128011531', 'Sylvania - Taren Point', Decimal('0.31143132840022784804'))
# Zbusiness: 0.31143132840022784804
# ('128011602', 'Caringbah', Decimal('0.33240247512069630605'))
# Zbusiness: 0.33240247512069630605
# ('128011603', 'Caringbah South', Decimal('-0.39110208673546549536'))
# Zbusiness: -0.39110208673546549536
# ('128011604', 'Cronulla - Kurnell - Bundeena', Decimal('1.1712483439394346'))
# Zbusiness: 1.1712483439394346
# ('128011605', 'Lilli Pilli - Port Hacking - Dolans Bay', Decimal('-0.60081355394015007548'))
# Zbusiness: -0.60081355394015007548
# ('128011606', 'Woolooware - Burraneer', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('128021533', 'Heathcote - Waterfall', Decimal('-0.65324142074132122051'))
# Zbusiness: -0.65324142074132122051
# ('128021534', 'Illawong - Alfords Point', Decimal('-0.38061651337523126635'))
# Zbusiness: -0.38061651337523126635
# ('128021535', 'Menai - Lucas Heights - Woronora', Decimal('-0.26527520641265474729'))
# Zbusiness: -0.26527520641265474729
# ('128021536', 'Oyster Bay - Como - Jannali', Decimal('-0.06604931256820439618'))
# Zbusiness: -0.06604931256820439618
# ('128021537', 'Royal National Park', Decimal('-0.73712600762319505255'))
# Zbusiness: -0.73712600762319505255
# ('128021538', 'Sutherland - Kirrawee', Decimal('0.42677263536280436710'))
# Zbusiness: 0.42677263536280436710
# ('128021607', 'Engadine', Decimal('-0.13944832608984399922'))
# Zbusiness: -0.13944832608984399922
# ('128021608', 'Loftus - Yarrawarrah', Decimal('-0.65324142074132122051'))
# Zbusiness: -0.65324142074132122051
# ('128021609', 'Woronora Heights', Decimal('-0.70566928754249236553'))
# Zbusiness: -0.70566928754249236553

# %% [markdown]
# # Calculate the Zstops

# %% [markdown]
# Zstops used to quantify the standardised deviation of the number of public transport stops in each SA2 region relative to the average number of stops throughout the Sydney region

# %% [markdown]
# the z-score formula is given by $z = \frac{X - \mu}{\sigma}$, where $X$ is the value, $\mu$ is the mean, and $\sigma$ is the standard deviation.
#
# The window function OVER() is used here to calculate the mean and standard deviation of all selected data

# %%
Zstops_data = db.execute('''
WITH stop_counts AS (
    SELECT 
        sa2_code, 
        COUNT(stop_id) AS total_stops
    FROM stops
    GROUP BY sa2_code
)

SELECT 
    sa2_code, 
    (total_stops - AVG(total_stops) OVER()) / (STDDEV(total_stops) OVER()) AS zstops
FROM stop_counts;

''')

for row in Zstops_data:
    print(row)
    Zstops = row[1]
    print(f"Zstops: {Zstops}")
# Out:
# (None, None)
# Zstops: None

# %% [markdown]
# # Calculate the Zpolls

# %% [markdown]
# Zpolls assess the standard deviation of the number of polling stations in each SA2 region from the average of the entire dataset.
#
# the z-score formula is given by $z = \frac{X - \mu}{\sigma}$, where $X$ is the value, $\mu$ is the mean, and $\sigma$ is the standard deviation.
#
# The window function OVER() is used here to calculate the mean and standard deviation of all selected data

# %%
Zpolls_data = db.execute('''
WITH poll_counts AS (
    SELECT
        sa2_code,
        COUNT(polling_place_id) AS total_polls
    FROM 
        polls
    GROUP BY 
        sa2_code
)

SELECT
    sa2_code,
    (total_polls - AVG(total_polls) OVER()) / (STDDEV(total_polls) OVER()) AS zpolls
FROM poll_counts;
''')

for row in Zpolls_data:
    print(row)
    Zpolls = row[1]
    print(f"Zpolls: {Zpolls}")
# Out:
# ('128011606', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125041588', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('127011504', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116021632', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('112031250', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('102021056', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('103041076', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('126021500', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('115041301', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('101051540', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('122031693', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('128011605', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('116021562', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('115011558', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('122031692', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('118021566', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111031227', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('107041549', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101021008', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('125011584', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('113031265', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('123011699', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('119021663', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021503', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('110031196', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('107031143', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('102011029', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('103021068', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('112031252', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('102021046', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('113031271', Decimal('4.3583957342026478'))
# Zpolls: 4.3583957342026478
# ('118011347', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('121031407', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('104021087', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('121041416', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('117011323', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125021712', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121011683', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('117031641', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('101041021', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('110041204', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106031122', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('111011214', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101051539', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('117021637', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('128021535', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('127021513', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112031253', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('116011626', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('117011635', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('124031707', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119021660', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('119041669', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('108021156', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('127021511', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('106031125', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('102011037', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('113031264', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('115011290', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('117031331', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('118021565', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('117031330', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116021563', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021724', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('121041688', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('116021630', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108021155', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('103021066', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('120031681', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('102011034', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('124011455', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('103031072', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('114011279', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125011586', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('102021052', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111011210', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('119011657', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101041026', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121021406', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('121011401', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106031119', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('119021573', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('124031708', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('109011175', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('115011554', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('114011273', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('105021097', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('104021085', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116031315', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127021520', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('120021675', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('107011132', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('113031268', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('120011383', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('124051469', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('121031412', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119011658', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('115011555', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101041024', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('215021469', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('120031680', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('125021478', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('112021249', Decimal('3.9181537408488450'))
# Zpolls: 3.9181537408488450
# ('108051170', Decimal('4.7986377275564506'))
# Zpolls: 4.7986377275564506
# ('118021568', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('113031270', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('105011093', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125011709', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('114021288', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108051169', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('127021515', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108021157', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107011546', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('113011256', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('125041491', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119011656', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('105031101', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('110011186', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('123021437', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('114021287', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127021518', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('110041205', Decimal('4.3583957342026478'))
# Zpolls: 4.3583957342026478
# ('109021179', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126011496', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('124031464', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('116031313', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('121041689', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('122031696', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('119031374', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('102011040', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('101061541', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('109031181', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('103021065', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('106021618', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('118011649', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('117031640', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('121011685', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121011684', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('102011042', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('124031459', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('102011028', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('101031016', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('121031411', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('123021706', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('113011259', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119041381', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('105011092', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111011206', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('102021053', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('119011358', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('126021590', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('122031430', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106041127', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127021510', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('120031392', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127021509', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('121011682', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('106031120', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('117031646', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('123021436', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('118021652', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('120031576', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('103041079', Decimal('3.4779117474950422'))
# Zpolls: 3.4779117474950422
# ('118011344', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('106031123', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127031523', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111021220', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('120011672', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111011211', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('125031479', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('118021567', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('114021289', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('115011556', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('110011189', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('109031184', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('124031461', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('126021723', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('126011720', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('123021444', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('119041379', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111031222', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('118021570', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103011613', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('101021007', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127011594', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121041417', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('127031601', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127011727', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('123021704', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('110041202', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('125041489', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('110031195', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('115021298', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111031231', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111021218', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('126021499', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('110021194', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('120021389', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('113031267', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('123021703', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('110031198', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('114011274', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125041589', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('103021064', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('112011242', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('125031713', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('121041413', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125041490', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('114011276', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('122031425', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('112021245', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('117031639', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('120011385', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119011572', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('107011131', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('112031550', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('110021190', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('108011154', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('116031316', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119031664', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('108041162', Decimal('3.0376697541412394'))
# Zpolls: 3.0376697541412394
# ('122031694', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('119021362', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119011354', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('116011306', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('109031180', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101041020', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('117031644', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119031370', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('110041203', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('109031185', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('102021051', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('127011729', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125011583', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('120021387', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('120031395', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('125011582', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('119011571', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106021116', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108011152', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('105021098', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('101031015', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('117031645', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('124051580', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('123031447', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('118011339', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('105031102', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('102011043', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111031235', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121031408', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('107031137', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('102011038', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111011208', Decimal('3.4779117474950422'))
# Zpolls: 3.4779117474950422
# ('104021086', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('103021069', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('112021246', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111021217', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119011655', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021725', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('118011340', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('105011094', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('115041624', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('117031648', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('110041201', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('103041078', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('122021691', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125041718', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('114011272', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127011726', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('120031396', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('117011634', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112031551', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('106041129', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('118021653', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125031481', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('125041493', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('111031226', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121011686', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('125041494', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('101021009', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('118011341', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('117031638', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('116011560', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('109031182', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('115021297', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('119021662', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('112021247', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('128021534', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('107031142', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101061543', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('117031336', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('106011113', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('124041467', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119041668', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119031372', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('107031138', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106011107', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('309021230', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('124011453', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108021158', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('119011360', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125041719', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('125041717', Decimal('3.0376697541412394'))
# Zpolls: 3.0376697541412394
# ('112021248', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('118011346', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('127031730', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('114021286', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('123011702', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('120031394', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125031480', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('117031643', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021501', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('123011700', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('124031465', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('113031269', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('128021609', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('117021328', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('122031695', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116031317', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('801051060', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('116011627', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('119011356', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('118021569', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('122031697', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('123031448', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('102021049', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('128021536', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('115031300', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('104021091', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('117031329', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('128011603', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('103021062', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('119031373', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('113031263', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('125011585', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('102021050', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111011213', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('104021088', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107031139', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('123011433', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('127011593', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('124041468', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103011061', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111031223', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('104021084', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108041620', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('113021262', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('120031393', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('107011545', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('128011602', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('122021422', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('105031103', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101021010', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('126011721', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('128021538', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('117021636', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111021221', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('117031642', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('128021533', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('104011080', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('122031429', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('107031141', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('106021114', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107011134', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('120011386', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119021661', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('101021012', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('127031733', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112031251', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125021477', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119031666', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('107041146', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('107041144', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('103041077', Decimal('3.4779117474950422'))
# Zpolls: 3.4779117474950422
# ('111011212', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('124031463', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108041619', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101041025', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('113011258', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('125031483', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('118011345', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021722', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('121021577', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('121041414', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('105031105', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103011612', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('106011109', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('105031106', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('102021045', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('105031100', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('128011604', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('116011303', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111031224', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('124031462', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('127011728', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111031232', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('111021215', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101031014', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101021611', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('125031716', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('127021514', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('101061544', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('128011530', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('117031647', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('125021711', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('112011237', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('119031371', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116011304', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('118021651', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('115011291', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('112011240', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('113021260', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('127031731', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106021614', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('121021579', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('216011406', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('101041019', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('127021512', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('107031140', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('102021057', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('123011701', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('122011419', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('112011238', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('111031229', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('114011281', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('121011399', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('109011172', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106021617', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('117011321', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('102011031', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('110011187', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('106011110', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('109021178', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('124031457', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('123021438', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('127021519', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('110041199', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('120031677', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119041382', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('114011278', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('105011095', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('104011082', Decimal('2.5974277607874366'))
# Zpolls: 2.5974277607874366
# ('106031124', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106021615', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107041548', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('114011280', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107041147', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103021067', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('118021654', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('115011621', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('112011243', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('125011710', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('122021421', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('109031183', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('125031714', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116031314', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('106031121', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('103031073', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108021159', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('104021090', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('124051581', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('119021367', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127031524', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('127011505', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('111031233', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('111021216', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('103031074', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('104021089', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('105011096', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('123031445', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112011236', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('110021193', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('107031136', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108041166', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('108011151', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('120031676', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('106021616', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('110021191', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('111021219', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('112021244', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('122031424', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112031552', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('112011239', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('110021192', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('127031599', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103031070', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('123021443', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('123021441', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108051167', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('127011596', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('114011283', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('114011277', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('104011081', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('122031427', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('125011587', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('110041200', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('124011454', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('108041165', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('120031679', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('107041145', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('111031228', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('115011296', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('116011307', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('105031104', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('107011547', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('102011035', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('121021403', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108051171', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('117031333', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('115041625', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('113031266', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('128021607', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('103011059', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('119041380', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101041023', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('121021404', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119031665', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('124011452', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('109021177', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('102011041', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('124031460', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('102021048', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('106011111', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('119021659', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('118021564', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('103021063', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('107041150', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('124041466', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('102011030', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('119011361', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('106041128', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101021610', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('119041377', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('118011650', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('110011188', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('106041126', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('116021309', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('128011531', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('108051168', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('108021160', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('102021047', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('121031409', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('112031254', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('102021044', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('108011153', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('117021327', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('106011112', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('115031299', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103011060', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('111011209', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('121011687', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116021633', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('105031099', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('127011597', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('122011418', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('119041378', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('115011294', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('123011698', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('120031678', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('114021284', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('104021083', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('101041027', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('101041017', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('103031071', Decimal('1.7169437740798309'))
# Zpolls: 1.7169437740798309
# ('123021705', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('120021674', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('102021054', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('101041018', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('114021285', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('112011241', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('108031161', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('101061542', Decimal('3.0376697541412394'))
# Zpolls: 3.0376697541412394
# ('114011282', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('108041164', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('102011039', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('116011561', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('126021498', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('122021690', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('127011595', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119021366', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('122021420', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('124051470', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('116031319', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('111011207', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('107041148', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('111031225', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('111031234', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127021521', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('109011174', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('128011529', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('121031410', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('101031013', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('124011450', Decimal('0.83645978737222533409'))
# Zpolls: 0.83645978737222533409
# ('106011108', Decimal('2.1571857674336338'))
# Zpolls: 2.1571857674336338
# ('128021608', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('116021628', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('113011257', Decimal('3.4779117474950422'))
# Zpolls: 3.4779117474950422
# ('102011033', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('115011553', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('123031446', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('120011673', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('119021574', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('124011449', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('121021578', Decimal('0.39621779401842252667'))
# Zpolls: 0.39621779401842252667
# ('113021261', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125031715', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('102021055', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127031732', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127021516', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('109011176', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('119031667', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('102011036', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('102011032', Decimal('1.27670178072602814150'))
# Zpolls: 1.27670178072602814150
# ('109011173', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('127021517', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('110031197', Decimal('-0.04402419933538028074'))
# Zpolls: -0.04402419933538028074
# ('125031484', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816
# ('127031522', Decimal('-0.92450818604298589557'))
# Zpolls: -0.92450818604298589557
# ('122031432', Decimal('-1.3647501793967887'))
# Zpolls: -1.3647501793967887
# ('119041670', Decimal('-0.48426619268918308816'))
# Zpolls: -0.48426619268918308816

# %% [markdown]
# # Calculate the Zschools

# %% [markdown]
# Zschools uses a standardised approach to measure where the number of school catchments in each region compares to the average for the entire Sydney region. This can help identify which regions are relatively rich in educational resources and which may need more attention and resource input.
#
# the z-score formula is given by $z = \frac{X - \mu}{\sigma}$, where $X$ is the value, $\mu$ is the mean, and $\sigma$ is the standard deviation.
#
# The window function OVER() is used here to calculate the mean and standard deviation of all selected data

# %%
Zschool_data = db.execute('''
WITH school_counts AS (
    SELECT 
        sa2_code, 
        COUNT(use_id) AS total_schools
    FROM 
        school
    GROUP BY 
        sa2_code
)


SELECT 
    sa2_code, 
    (total_schools - AVG(total_schools) OVER()) / (STDDEV(total_schools) OVER()) AS zschools
FROM school_counts;

''')

for row in Zschool_data:
    print(row)
    Zschool = row[1]
    print(f"Zschool: {Zschool}")
# Out:
# ('101051539', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('101051540', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('102011030', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('103021062', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('103021069', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('103031071', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('103041076', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('103041079', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('104011081', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('104011082', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('104021087', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('104021089', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('105011092', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('105021097', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('105021098', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('105031105', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('106011108', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('106011109', Decimal('1.39677044641174484487'))
# Zschool: 1.39677044641174484487
# ('106011112', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('106021614', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('107041146', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('107041150', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('108021155', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('108021156', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('108051169', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('108051170', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('109011175', Decimal('2.3186389410434964'))
# Zschool: 2.3186389410434964
# ('109011176', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('109021179', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('109031180', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('109031181', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('109031183', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('110011186', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('110011188', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('110021192', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('110031196', Decimal('1.39677044641174484487'))
# Zschool: 1.39677044641174484487
# ('110031198', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('110041205', Decimal('2.3186389410434964'))
# Zschool: 2.3186389410434964
# ('111011206', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('111011209', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('111021219', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('112011237', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('112021245', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('112021249', Decimal('6.0061129195705027'))
# Zschool: 6.0061129195705027
# ('113011256', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('113011257', Decimal('1.39677044641174484487'))
# Zschool: 1.39677044641174484487
# ('113011258', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('113011259', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('113031265', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('113031271', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('114011279', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('114021288', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('114021289', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('116011307', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('116031316', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('119011658', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('123011699', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('123021438', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('123021443', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('123021706', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('124031462', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('124051470', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('125021477', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('127031523', Decimal('-0.44696654285175829136'))
# Zschool: -0.44696654285175829136
# ('127031524', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
# ('128021538', Decimal('0.47490195177999327675'))
# Zschool: 0.47490195177999327675
